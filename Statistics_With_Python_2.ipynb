# %%
data2 = [24,12,32,45,32,45,56,67,32]

# %%
import seaborn as sns

# %%
sns.histplot(data2)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data2, binwidth = 7)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data2, binwidth = 10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data2, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Kde = kernel density enstimate - smoothen the histogram graph

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data["sepal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data["sepal_length"], kde = True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data["sepal_width"], kde = True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data["petal_width"], kde = True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data["petal_length"], kde = True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
data2
# Out:
# [24, 12, 32, 45, 32, 45, 56, 67, 32]

# %%
data2
# Out:
# [24, 12, 32, 45, 32, 45, 56, 67, 32, 150, 250]

# %%
sns.histplot(data2, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# with outliers in right, graph is right skewed

# %%
data2.pop()
# Out:
# 250

# %%
data2.pop()
# Out:
# 150

# %%
data2
# Out:
# [24, 12, 32, 45, 32, 45, 56, 67, 32]

# %%
data2.insert(0, -40)

# %%
data2
# Out:
# [-40, 24, 12, 32, 45, 32, 45, 56, 67, 32]

# %%
data2.insert(0, -150)

# %%
data2
# Out:
# [-150, -40, 24, 12, 32, 45, 32, 45, 56, 67, 32]

# %%
sns.histplot(data2, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# With outliers in left, the graph is left skewed.

# %%
import numpy as np

# %%
nd = np.random.normal(0.5,0.2, 1000)       # will give normal distribution

# %%
# mean = 0.5, std = 0.5, count = 1000

# %%
sns.histplot(nd, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
mu = mean = 3.0
sigma = std = 1.0

# %%
v = np.random.lognormal(3.0, 1, 1000)

# %%
v
# Out:
# array([ 55.08717893,  15.96775312,   8.82284542,  14.37875273,
#         12.43290826,   9.5326526 ,   5.23558095,   6.75363803,
#          8.34723094,  10.07433605,  19.13510681,  56.10747889,
#         14.53932309,  45.61720797,  67.74120093,  82.60989522,
#         13.04036943,   5.74806453,   3.31142642,  46.40435724,
#          9.57907261,  31.97401942,  33.98451834,   4.17913876,
#         42.39444097,  45.54647891,   1.44464635,  45.55761567,
#          1.78933546,   9.07872507,  14.39432731,  34.68630503,
#         47.39406646, 110.6152754 ,  18.9955615 ,  15.8735295 ,
#         14.78787372,  23.12414911,  33.82292979,  10.02173355,
#         14.05985358,  18.62397288,  75.40790555,   9.1586115 ,
#          6.52494984,  13.64695069,  44.65948646,   7.65960655,
#         99.49058446,  50.50782978,  11.21473685,  15.43466157,
#         26.54482444,  40.89584075,  45.22863711,   4.91683633,
#         18.4992456 ,  29.318425  ,  47.65592318,  19.8182079 ,
# ...

# %%
sns.histplot(v, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
#  This is our lognormal distribution

# %%
# How to make it Normal distribution?

# %%
sns.histplot(np.log(v), kde =True)
# Out:
# <Axes: ylabel='Count'>

# %%
# This is close to normal distribution

# %%
var = np.random.normal(5.0, 1.0, 200)

# %%
sns.histplot(var, kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# This is a normal distribution. How to convert it into lognormal?

# %%
sns.histplot(np.exp(var), kde = True)
# Out:
# <Axes: ylabel='Count'>

# %%
# This is a lognoraml distribution

# %% [markdown]
# ### Q-Q Plot (Quantile- Quantile Plot)

# %% [markdown]
# 1. A q-q plot is a plot of the quantiles of the first data set against the quantiles of the second data set. By a quantile, we mean the fraction (or percent) of points below the given value. That is, the 0.3 (or 30%) quantile is the point at which 30% percent of the data fall below and 70% fall above that value.
# 2. In statistics, a Q–Q plot (quantile-quantile plot) is a probability plot, a graphical method for comparing two probability distributions by plotting their quantiles against each other.[1] A point (x, y) on the plot corresponds to one of the quantiles of the second distribution (y-coordinate) plotted against the same quantile of the first distribution (x-coordinate).
# 3. If the two distributions being compared are similar, the points in the Q–Q plot will approximately lie on the identity line y = x. If the distributions are linearly related, the points in the Q–Q plot will approximately lie on a line, but not necessarily on the line y = x.
# 4. A Q–Q plot is used to compare the shapes of distributions, providing a graphical view of how properties such as location, scale, and skewness are similar or different in the two distributions

# %%
# For more info read :- https://www.geeksforgeeks.org/qqplot-quantile-quantile-plot-in-python/

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
data2.remove(-150)

# %%
data2.remove(-40)

# %%
data2
# Out:
# [24, 12, 32, 45, 32, 45, 56, 67, 32]

# %%
plot_data(data2)

# %%
plot_data(v)

# %%
plot_data(var)

# %%
# For Normal distribution, the dots will be closer to the straight line.

# %%
# Hence, with qq plot, we can ccheck whether the graph is noramlly distributed or not.

# %%
data3 = sns.load_dataset("titanic")

# %%
data3.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
import pandas_profiling

# %%
profile = data3.profile_report()

# %%
# profile.to_file(output_file="output.html")

# This will create a html output file which will have all the stastistical informations about the datasets.
